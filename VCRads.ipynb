# %% [markdown]
# # Venture Capital In Radiology

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('VCRadsLinePlot.xlsx')
df = df[0:24]
# df['Year']. astype(int)
# df['Company Count']. astype(int)
# df['Deal Count']. astype(int)

# %%
sns.barplot(data = df, x="Year", y="Company Count", palette='dark')
# sns.set('dark')
# sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.set_palette("dark")

# %%
# fig, ax = plt.subplots()
# ax.bar(df['Year'], df['Capital Invested'], color="black", alpha=0.5)
# ax2 = ax.twinx()
# sns.lineplot(x='Year', y='Deal Count', data=df, ax=ax2, color='navy')
# # sns.plt.show()
# ax.legend(['Capital Invested'], loc='upper left', bbox_to_anchor=(1.055, 1.0))
# ax2.legend(['No. of Investments'], loc='upper right', bbox_to_anchor=(1.265, 0.9))
# ax.set_ylim(0, 3000)
# ax2.set_ylim(0, 400)
# plt.title('Annual Venture Capital Investment in Radiology Companies', loc='center')
# plt.grid()

# ax.set_ylabel('Total Venture Capital Investment, $1 Million')
# ax.set_xlabel('Study Year')
# ax2.set_ylabel('Total No. Investments')

# x = np.arange(2000, 2024, step=2)
# # ax.tick_params(labelrotation=45)
# plt.xticks(x, rotation=45)
# plt.xlabel('Study Year')

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(False)
# ax2.spines['top'].set_visible(False)
# ax2.spines['right'].set_visible(False)
# ax2.spines['left'].set_visible(False)

# [s.set_visible(False) for s in ax.spines.values()]
# [t.set_visible(False) for t in ax.get_xticklines()]
# [t.set_visible(False) for t in ax.get_yticklines()]
# [s.set_visible(False) for s in ax2.spines.values()]
# [t.set_visible(False) for t in ax2.get_xticklines()]
# [t.set_visible(False) for t in ax2.get_yticklines()]

# fig.set_figwidth(12)
# fig.set_figheight(5)

# %%
# df['Capital Invested'][0:23]

df['Percent Change'] = df['Capital Invested'].div(df['Capital Invested'].shift())

# %%
df['Percentage Change'] = 1/df['Percent Change']

# %%
sum(df['Percentage Change'][1:])/len(df['Percentage Change'][1:])
# Out:
# 7.032369719100738

# %%
(sum(df['Percentage Change'][1:]) - 69 - 65)/(len(df['Percentage Change'][1:])-2)
# Out:
# 1.3211668352055705

# %%
sum(df['Capital Invested'])
# Out:
# 11789.1

# %%
sum(df['Deal Count'])
# Out:
# 2564

# %% [markdown]
# ## Final Plot

# %%
fig, ax = plt.subplots()
ax.bar(df['Year'], df['Deal Count'], color="black", alpha=0.5)
ax2 = ax.twinx()
sns.lineplot(x='Year', y='Capital Invested', data=df, ax=ax2, color='navy')
# sns.plt.show()
ax.legend(['Deal Count'], loc='upper left', bbox_to_anchor=(1.04, 1.0))
ax2.legend(['Capital Invested'], loc='upper right', bbox_to_anchor=(1.155, 0.925))
ax.set_ylim(0, 400)
ax2.set_ylim(0, 2500)
plt.grid()

ax.set_ylabel('Total No. Investments')
ax.set_xlabel('Study Year')
ax2.set_ylabel('Total Venture Capital Investment, $1 Million')


x = np.arange(2000, 2024, step=2)
# ax.tick_params(labelrotation=45)
plt.xticks(x, rotation=45)
plt.xlabel('Study Year')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

[s.set_visible(False) for s in ax.spines.values()]
[t.set_visible(False) for t in ax.get_xticklines()]
[t.set_visible(False) for t in ax.get_yticklines()]
[s.set_visible(False) for s in ax2.spines.values()]
[t.set_visible(False) for t in ax2.get_xticklines()]
[t.set_visible(False) for t in ax2.get_yticklines()]

fig.set_figwidth(12)
fig.set_figheight(5)



fig.set_size_inches(20, 8) # set figure's size manually to your full screen (32x18)
plt.savefig('VCRadsFigure1.jpg', bbox_inches='tight')
